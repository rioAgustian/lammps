# %%
import numpy as np
import matplotlib.pyplot as plt

file = r"C:\Users\Rio Agustian\AppData\Local\LAMMPS 64-bit 12Jun2025\DATA\water-adsoption-in-silica\number_data.txt"

# Data
data = np.loadtxt(file, skiprows=1)
steps = data[:, 0] * 0.001
temp = data[:, 1]
etot = data[:, 2] * 0.001
vol = data[:, 3]
dens = data[:, 4]

plt.figure(figsize=(12, 6))

plt.subplot(211)
plt.plot(steps, temp, color='blue')
plt.vlines(x=10, ymin=2, ymax=7000, color='k', ls='--')
plt.vlines(x=40, ymin=2, ymax=7000, color='k', ls='--')
plt.yticks([0, 2000, 4000, 6000])
plt.ylim(0, 7000)
plt.ylabel("T (K)")
plt.gca().axes.xaxis.set_visible(False)

plt.subplot(212)
plt.plot(steps, dens, color='blue')
plt.xticks(list(np.arange(0, 55, 10)))
plt.yticks(list(np.arange(2.0, 2.55, 0.1)))
plt.vlines(x=10, ymin=2, ymax=2.55, color='k', ls='--')
plt.vlines(x=40, ymin=2, ymax=2.55, color='k', ls='--')
plt.xlabel("t (ps)")
plt.ylabel(r"$\rho \, (g/cm^3)$")

plt.tight_layout()  # Adjust layout to fit suptitle
plt.savefig("my_plot_2.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

file = r"C:\Users\Rio Agustian\AppData\Local\LAMMPS 64-bit 12Jun2025\DATA\water-adsoption-in-silica\number_data.txt"

# Data
data = np.loadtxt(file, skiprows=1)
steps = data[:, 0] * 0.001
temp = data[:, 1]
etot = data[:, 2] * 0.001
vol = data[:, 3]
dens = data[:, 4]
nO = data[:, 6]

plt.figure(figsize=(12, 3))
plt.plot(steps, nO, color='blue')
plt.ylabel("$N_{h_2O}$)")
plt.xlabel("t (ps)")
plt.savefig("my_plot_2.png")
plt.show()
